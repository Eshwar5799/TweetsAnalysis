# %% [markdown]
# This Project uses 1 csv files downloaded from IEEE.org and consists of > 7,00,000 tweets

# %% [markdown]
# # Glimpses of the dataset

# %%
import pandas as pd
import numpy as np
import time

# %%
csv_1 = pd.read_csv("DataSet-MajorProject/corona_tweets_01.csv")

# %%
#  Sample Converting tweet ID to time and date

# %%
tweet_id = 1241032864130650113
shifted_id = tweet_id >> 22 #applying right shift operator to the tweet ID
timestamp = shifted_id + 1288834974657 
data_time = time.ctime(timestamp/1000)
print(data_time)
# Out:
# Fri Mar 20 21:34:26 2020

# %%
# Hydrating tweets Converting tweetId to Text and Store it in a Database

# %%
Dataset = pd.read_csv("DataSet-MajorProject/Dataset-PreProcessed -TweetIDfinaldone.csv")
Dataset
# Out:
#       coordinates                      created_at hashtags  \
# 0             NaN  Thu Mar 19 19:52:18 +0000 2020      NaN
# 1             NaN  Thu Mar 19 19:52:17 +0000 2020      NaN
# 2             NaN  Thu Mar 19 19:52:18 +0000 2020      NaN
# 3             NaN  Thu Mar 19 19:52:15 +0000 2020      NaN
# 4             NaN  Thu Mar 19 19:52:16 +0000 2020      NaN
# ...           ...                             ...      ...
# 30926         NaN  Thu Mar 19 20:16:59 +0000 2020      NaN
# 30927         NaN  Thu Mar 19 20:16:58 +0000 2020      NaN
# 30928         NaN  Thu Mar 19 20:17:01 +0000 2020      NaN
# 30929         NaN  Thu Mar 19 20:17:00 +0000 2020      NaN
# 30930         NaN  Thu Mar 19 20:17:00 +0000 2020      NaN
#
#                                                    media urls  favorite_count  \
# 0                                                    NaN  NaN               0
# 1                                                    NaN  NaN               0
# ...

# %%
#Create a Seperate file for tweet_id , corresponding tweet , GeoLocation , user_verified

# %%
df = pd.DataFrame(Dataset)

# %%
df.columns
# Out:
# Index(['coordinates', 'created_at', 'hashtags', 'media', 'urls',
#        'favorite_count', 'id', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_user_id', 'lang', 'place',
#        'possibly_sensitive', 'retweet_count', 'retweet_id',
#        'retweet_screen_name', 'source', 'text', 'tweet_url', 'user_created_at',
#        'user_screen_name', 'user_default_profile_image', 'user_description',
#        'user_favourites_count', 'user_followers_count', 'user_friends_count',
#        'user_listed_count', 'user_location', 'user_name', 'user_screen_name.1',
#        'user_statuses_count', 'user_time_zone', 'user_urls', 'user_verified'],
#       dtype='object')

# %%
created = df['created_at']
texts = df['text']
location = df['user_location']
verified = df['user_verified']

# %%
fields = [created , texts , location , verified]

# %%
fields[2]
# Out:
# 0                London, England
# 1               Close to America
# 2                            NaN
# 3        Sydney, New South Wales
# 4                            NaN
#                   ...
# 30926                        eug
# 30927                    Buffalo
# 30928                       USA😍
# 30929                        NaN
# 30930            Kampala, Uganda
# Name: user_location, Length: 30931, dtype: object

# %%
d = {'User-Created':fields[0],'Tweet':fields[1],'Geo-location':fields[2],'verified':fields[3]}

# %%
dfq=pd.DataFrame(d)

# %%
dfq
# Out:
#                          User-Created  \
# 0      Thu Mar 19 19:52:18 +0000 2020
# 1      Thu Mar 19 19:52:17 +0000 2020
# 2      Thu Mar 19 19:52:18 +0000 2020
# 3      Thu Mar 19 19:52:15 +0000 2020
# 4      Thu Mar 19 19:52:16 +0000 2020
# ...                               ...
# 30926  Thu Mar 19 20:16:59 +0000 2020
# 30927  Thu Mar 19 20:16:58 +0000 2020
# 30928  Thu Mar 19 20:17:01 +0000 2020
# 30929  Thu Mar 19 20:17:00 +0000 2020
# 30930  Thu Mar 19 20:17:00 +0000 2020
#
#                                                    Tweet  \
# 0      RT @ebs_the_great: A lot of you would actually...
# 1      RT @iam_erhnehst: Everything was fine in the w...
# 2      RT @chandlerriggs: here’s a deleted scene from...
# 3         RT @RealSaavedra: Good.\n\nIt came from China.
# 4      RT @TattooedFemdom: My dick is Bigger than Cor...
# ...                                                  ...
# 30926  RT @d_psycho_guru: I just tested positive to t...
# ...

# %%
# Save this DataFrame
dfq.to_csv('DataSet-MajorProject/FinalCleanedDB')

# %%
# Dataset

# %%
DB = pd.read_csv("DataSet-MajorProject/FinalCleanedDB")

# %%
DB
# Out:
#        Unnamed: 0                    User-Created  \
# 0               0  Thu Mar 19 19:52:18 +0000 2020
# 1               1  Thu Mar 19 19:52:17 +0000 2020
# 2               2  Thu Mar 19 19:52:18 +0000 2020
# 3               3  Thu Mar 19 19:52:15 +0000 2020
# 4               4  Thu Mar 19 19:52:16 +0000 2020
# ...           ...                             ...
# 30926       30926  Thu Mar 19 20:16:59 +0000 2020
# 30927       30927  Thu Mar 19 20:16:58 +0000 2020
# 30928       30928  Thu Mar 19 20:17:01 +0000 2020
# 30929       30929  Thu Mar 19 20:17:00 +0000 2020
# 30930       30930  Thu Mar 19 20:17:00 +0000 2020
#
#                                                    Tweet  \
# 0      RT @ebs_the_great: A lot of you would actually...
# 1      RT @iam_erhnehst: Everything was fine in the w...
# 2      RT @chandlerriggs: here’s a deleted scene from...
# 3         RT @RealSaavedra: Good.\n\nIt came from China.
# 4      RT @TattooedFemdom: My dick is Bigger than Cor...
# ...
